# %%
print(111)
# Out:
# 111

# %%
print(222)
a = 10
if a > 5:
    print('bigger than 5')
# Out:
# 222
# bigger than 5

# %% [markdown]
# ### a 위에 생성 b 밑에 생성 m 마크다운 #3개 글씨 크게 ctrl+ent 결과보기 // 문서정리할 때 이거 사용

# %% [markdown]
# ![image](test.jpg)

# %%
import matplotlib.pyplot as plt

# 데이터
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 그래프 그리기
plt.plot(x, y)

# 제목과 라벨
plt.title("Simple Line Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")

# 표시
plt.show()
